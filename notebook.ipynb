# %% [markdown]
# # كيف تُكرّر هذه التجربة في 60 ثانية؟ | How to Reproduce This Experiment in 60 Seconds?
#
# ## الطريقة السريعة | Quick Method
#
# إذا كنت تفضل استخدام الطرفية بدلاً من Jupyter:
#
# ```bash
# pip install matplotlib numpy
# cd code
# python quran_hearts.py
# ```
#
# هذا كل شيء! 🎉
#
# ---
#
# ## الطريقة باستخدام Jupyter | Jupyter Method
#
# انتقل للخلية التالية واضغط **Run All**

# %%
"""
Rahman-Key: Generate All 114 Quranic Digital Hearts
Click Run All to generate all images automatically!
"""

import sys
import os
from pathlib import Path

# Add code directory to path
sys.path.insert(0, str(Path('code')))

# Import the main function
from quran_hearts import generate_all_hearts

# Generate all 114 hearts
print("🚀 Starting generation of 114 Quranic Digital Hearts...")
print("=" * 60)
generate_all_hearts()
print("=" * 60)
print("✅ Complete! All images saved in 'images/' directory")
print("✅ Pattern descriptions saved in 'descriptions.json'")
