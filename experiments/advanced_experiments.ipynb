# %% [markdown]
# # 🔬 Advanced Experiments | التجارب المتقدمة
#
# ## Rahman Key (31×6) - Advanced Discoveries
# ## مفتاح الرحمن (31×6) - الاكتشافات المتقدمة
#
# This notebook contains advanced experiments applying the Rahman Key methodology to:
# - 99 Names of Allah
# - Heart verses in Quran (57 verses)
# - Verses starting with "O Believers" (88 verses)
# - Basmalah (114 times)
#
# هذا الـ notebook يحتوي على تجارب متقدمة تطبق منهجية مفتاح الرحمن على:
# - أسماء الله الحسنى (99)
# - آيات القلب في القرآن (57 آية)
# - آيات "يا أيها الذين آمنوا" (88 آية)
# - البسملة (114 مرة)
#
# ---
#
# ## ⚠️ Important Note | ملاحظة مهمة
#
# **English:**
# Visual interpretations (crown, lock, key, hands, halo, etc.) are **subjective observations** — they are **NOT part of the algorithmic methodology**. The code generates raw bitmap images only.
#
# **العربية:**
# التفسيرات البصرية (تاج، قفل، مفتاح، يدين، هالة، إلخ) هي **ملاحظات ذاتية** — وهي **ليست جزءاً من المنهجية الخوارزمية**. الكود يولد صور bitmap خام فقط.
#
# ---
#
# ## 🚀 Quick Start | التشغيل السريع
#
# Click **Run All** to generate all advanced experiment images automatically!
#
# اضغط **Run All** لتوليد جميع صور التجارب المتقدمة تلقائياً!

# %%
"""
Setup: Import required libraries
إعداد: استيراد المكتبات المطلوبة
"""
import sys
from pathlib import Path

# Add experiments directory to path
sys.path.insert(0, str(Path(__file__).parent if '__file__' in globals() else Path.cwd()))

print("✅ Libraries ready | المكتبات جاهزة")

# %% [markdown]
# ## 1. 99 Names of Allah | أسماء الله الحسنى

# %%
"""
99 Names of Allah - Rahman Key Experiment
أسماء الله الحسنى - تجربة مفتاح الرحمن
"""
from names_of_allah import generate_names_99

print("=" * 60)
print("99 Names of Allah - Rahman Key Experiment")
print("أسماء الله الحسنى - تجربة مفتاح الرحمن")
print("=" * 60)
generate_names_99()
print("=" * 60)
print("✅ Complete!")

# %% [markdown]
# ## 2. Heart Verses in Quran | آيات القلب في القرآن

# %%
"""
Heart Verses in Quran - Rahman Key Experiment
آيات القلب في القرآن - تجربة مفتاح الرحمن
"""
from hearts_in_quran import main as generate_hearts

generate_hearts()

# %% [markdown]
# ## 3. Verses "O Believers" | آيات "يا أيها الذين آمنوا"

# %%
"""
Verses Starting with "O Believers" - Rahman Key Experiment
آيات "يا أيها الذين آمنوا" - تجربة مفتاح الرحمن
"""
from ya_ayyuhal_ladhina_amanu import generate_believers_heart

print("=" * 60)
print('Verses "O Believers" - Rahman Key Experiment')
print('آيات "يا أيها الذين آمنوا" - تجربة مفتاح الرحمن')
print("=" * 60)
generate_believers_heart()
print("=" * 60)
print("✅ Complete!")

# %% [markdown]
# ## 4. Basmalah (114 times) | البسملة (114 مرة)

# %%
"""
Basmalah (114 times) - Rahman Key Experiment
البسملة (114 مرة) - تجربة مفتاح الرحمن
"""
from basmalah_114 import generate_basmalah_heart

print("=" * 60)
print("Basmalah (114 times) - Rahman Key Experiment")
print("البسملة (114 مرة) - تجربة مفتاح الرحمن")
print("=" * 60)
generate_basmalah_heart()
print("=" * 60)
print("✅ Complete!")

# %% [markdown]
# ## 📊 Summary | الملخص
#
# **English:**
# All experiments have been completed! Check the `experiments_output/` directory for generated images.
#
# **العربية:**
# اكتملت جميع التجارب! تحقق من مجلد `experiments_output/` للصور المولدة.
#
# ### Generated Images | الصور المولدة:
#
# - `experiments_output/names_of_allah/099_Names_Of_Allah.png`
# - `experiments_output/hearts_quran/Hearts_VerseOrder.png`
# - `experiments_output/hearts_quran/Hearts_AbsoluteNumbers.png`
# - `experiments_output/ya_ayyuhal_ladhina_amanu/Yaa_Ayyuhal_Ladhina_Amanu_88.png`
# - `experiments_output/basmalah/Basmalah_114.png`
#
# ---
#
# **🌙 Rahman-Key** — Exploring numerical patterns, one experiment at a time. | استكشاف الأنماط العددية، تجربة تلو الأخرى.
